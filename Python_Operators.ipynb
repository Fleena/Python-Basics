# %%
# 1. Import keyword library and print list of keywords along with total number of keywords

import keyword
key_words = keyword.kwlist
print(key_words)
len(key_words)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %%
# 2. In Markdown State, Copy Python keywords image from GoogleImages and Paste it in your notebook

# %% [markdown]
# ![Python_keywords.jpg](attachment:Python_keywords.jpg)

# %%
# 3. Create two strings a and b with any integer values stored in it And perform Addition, Multiplication, Subtraction and a2+b2

a = 33
b = 42
c = a + b
d = a * b
e = a - b
f = (a**2) + (b**2)
print(c,d,e,f,sep='\n')
# Out:
# 75
# 1386
# -9
# 2853

# %%
# 4. Use Boolean operators (==, !=, >, >=, <, <= ) , between a and b and Display output

a = 78
b = 90
print(a == b)
print(a != b)
print(a > b)
print(a >= b)
print(a < b)
print(a <= b)
# Out:
# False
# True
# False
# False
# True
# True

# %%
#5. Create two strings x and y with any integer values stored in it And perform bitwise operations (&,^, | ,>>,<<)

x = 55
y = 26
print(bin(x))
print(bin(y))
print(bin(x & y))
print(x & y)
print(bin(x ^ y))
print(x ^ y)
print(bin(x | y))
print(x | y)
print(bin(x << 2))
print(x << 2)
print(bin(x >> 2))
print(x >> 2)
# Out:
# 0b110111
# 0b11010
# 0b10010
# 18
# 0b101101
# 45
# 0b111111
# 63
# 0b11011100
# 220
# 0b1101
# 13
