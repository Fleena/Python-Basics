# %%
import os
import pandas as pd

# %%
# Get current working directory
os.getcwd()
# Out:
# 'C:\\Users\\freya\\Downloads\\UpdatedResourceMaterials\\Day2'

# %%
#os.chdir()

# %%
# Reading CSV file
# variableName = pd.read_csv("FileName.csv")
honeyproduction = pd.read_csv(r"C:\Users\freya\Downloads\UpdatedResourceMaterials\DataFiles\honeyproduction.csv")
honeyproduction
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
honeyproduction.columns
# Out:
# Index(['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb',
#        'prodvalue', 'year'],
#       dtype='object')

# %%
honeyproduction.shape
# Out:
# (626, 8)

# %%
honeyproduction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
# variableName = pd.read_csv("Filepath/FileName.csv")
liedetector = pd.read_csv(r"C:\Users\freya\Downloads\UpdatedResourceMaterials\DataFiles\liedetector.csv")
liedetector
# Out:
#           X1       X2        X3       X4       X5  X6
# 0      P_001  3.62160   8.66610  -2.8073 -0.44699   0
# 1      P_002  4.54590   8.16740  -2.4586 -1.46210   0
# 2      P_003  3.86600  -2.63830   1.9242  0.10645   0
# 3      P_004  3.45660   9.52280  -4.0112 -3.59440   0
# 4      P_005  0.23230  -4.45520   4.5718 -0.98880   0
# ...      ...      ...       ...      ...      ...  ..
# 1367  P_1368  0.40614   1.34920  -1.4501 -0.55949   0
# 1368  P_1369 -1.38870  -4.87730   6.4774  0.34179   0
# 1369  P_1370 -3.75030 -13.45860  17.5932 -2.77710   0
# 1370  P_1371 -3.56370  -8.38270  12.3930 -1.28230   0
# 1371  P_1372 -2.54190  -0.65804   2.6842  1.19520   0
#
# [1372 rows x 6 columns]

# %%
liedetector.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6'], dtype='object')

# %%
liedetector.shape
# Out:
# (1372, 6)

# %%
liedetector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      1372 non-null   object
#  1   X2      1372 non-null   float64
#  2   X3      1372 non-null   float64
#  3   X4      1372 non-null   float64
#  4   X5      1372 non-null   float64
#  5   X6      1372 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 64.4+ KB

# %%
# Setting current working directory
os.chdir('/Users/freya/Downloads/UpdatedResourceMaterials/Day2')
os.getcwd()
# Out:
# 'C:\\Users\\freya\\Downloads\\UpdatedResourceMaterials\\Day2'

# %%
liedetectorNew = pd.read_csv("liedetector.csv")
liedetectorNew
# Out:
#           X1       X2        X3       X4       X5  X6
# 0      P_001  3.62160   8.66610  -2.8073 -0.44699   0
# 1      P_002  4.54590   8.16740  -2.4586 -1.46210   0
# 2      P_003  3.86600  -2.63830   1.9242  0.10645   0
# 3      P_004  3.45660   9.52280  -4.0112 -3.59440   0
# 4      P_005  0.23230  -4.45520   4.5718 -0.98880   0
# ...      ...      ...       ...      ...      ...  ..
# 1367  P_1368  0.40614   1.34920  -1.4501 -0.55949   0
# 1368  P_1369 -1.38870  -4.87730   6.4774  0.34179   0
# 1369  P_1370 -3.75030 -13.45860  17.5932 -2.77710   0
# 1370  P_1371 -3.56370  -8.38270  12.3930 -1.28230   0
# 1371  P_1372 -2.54190  -0.65804   2.6842  1.19520   0
#
# [1372 rows x 6 columns]

# %%
liedetectorNew.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6'], dtype='object')

# %%
liedetectorNew.shape
# Out:
# (1372, 6)

# %%
liedetectorNew.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      1372 non-null   object
#  1   X2      1372 non-null   float64
#  2   X3      1372 non-null   float64
#  3   X4      1372 non-null   float64
#  4   X5      1372 non-null   float64
#  5   X6      1372 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 64.4+ KB

# %%
# Reading excel file
salesData = pd.read_excel("Sales_data.xlsx", sheet_name='Sheet1')
salesData
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#       ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
salesData.shape
# Out:
# (2747, 20)

# %%
salesData.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'POSTALCODE', 'COUNTRY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
salesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   datetime64[ns]
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
# Crating data frame subset
salesDataSubset = salesData[['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER']]
salesDataSubset
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER
# 0           10107               30      95.70                2
# 1           10121               34      81.35                5
# 2           10134               41      94.74                2
# 3           10145               45      83.26                6
# 4           10168               36      96.66                1
# ...           ...              ...        ...              ...
# 2742        10350               20     112.22               15
# 2743        10373               29     137.19                1
# 2744        10386               43     125.99                4
# 2745        10397               34      62.24                1
# 2746        10414               47      65.52                9
#
# [2747 rows x 4 columns]

# %%
#os.getcwd()

# %%
# Writing into csv file
salesDataSubset.to_csv("salesDataSubset.csv")

# %%
salesDataSubset.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER
# count   2747.000000      2747.000000  2747.000000      2747.000000
# mean   10259.761558        35.103021   101.098951         6.491081
# std       91.877521         9.762135    42.042548         4.230544
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10181.000000        27.000000    68.745000         3.000000
# 50%    10264.000000        35.000000    95.550000         6.000000
# 75%    10334.500000        43.000000   127.100000         9.000000
# max    10425.000000        97.000000   252.870000        18.000000
